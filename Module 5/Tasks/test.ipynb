# %%
"{!s}".format("hello")
# Out:
# 'hello'

# %%
"{0} {1}".format("one", "two", "three")
# Out:
# 'one two'

# %%
"%s, %s, how are you?" % ("Hello", "Vetit")
# Out:
# 'Hello, Vetit, how are you?'

# %%
price = -125.6821
name = "Vetit"
print_func = print

f"The price is {price:.2f}, the name is {name}, print_func: {print_func}"
# Out:
# 'The price is -125.68, the name is Vetit, print_func: <built-in function print>'

# %% [markdown]
# # Encoding
#
# ### ASCII

# %%
# convert character to ASCII
ord('s')
# Out:
# 115

# %%
# convert ASCII to character
chr(1200)
chr(0x110000-1)
# Out:
# '\U0010ffff'

# %%
ord('h')
# Out:
# 104

# %%
chr(0x68)
# Out:
# 'h'

# %%
hex(int('10101010010101', 2))
# Out:
# '0x9'

# %% [markdown]
# Base 16 -> Hexadecimal -> RAM adress, Colors.
# Base 10 -> Human Interpretation
# Base 2 -> Computer Understanding

# %%
bin(12412)
# Out:
# '0b11000001111100'
